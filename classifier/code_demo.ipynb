# %% [markdown]
# ## Demonstrating the Classifier with the Adaptive STFT as front-end

# %% [markdown]
# #### Evolution of window length across eopchs for different initializations

# %% [markdown]
# Demo of the Adaptive Classifier. To run the code, provide the following arguments as inputs while running the code:
# 1. list of N to initialize classifier with: [10,15,20,25,30,45,55,65,70]
# 2. learning rate: 1e-1
# 3. number of epochs: 1000

# %%
run classifier_adaptive.py [10,15,20,25,30,45,55,65,70] 1e-1 1000
# Out:
# ...
# 100%|██████████| 1000/1000 [03:35<00:00,  4.64it/s]

# %% [markdown]
# #### STFT for different window lengths along with the classifier loss

# %% [markdown]
# Demo for obtaining the loss function as a function of the window size N. The command line inputs are the same as before, except the first one is now the different windows sizes to conside while computing the STFT)
# Note: Unlike the previous case, the window size is fixed apriori, and the classifier is then trained with this window size.

# %%
run classifier_ordinary.py [5,10,40,60,70] 1e-1 2000
# Out:
# ...
# 100%|██████████| 2000/2000 [01:11<00:00, 28.13it/s]
# /mnt/c/Users/subra/Desktop/PhD/Manuscripts/DiffASP_ICASSP2021/STFTgrad/classifier/classifier_ordinary.py:131: MatplotlibDeprecationWarning: Passing raw data via parameters data and lut to register_cmap() is deprecated since 3.3 and will become an error two minor releases later. Instead use: register_cmap(cmap=LinearSegmentedColormap(name, data, lut))
